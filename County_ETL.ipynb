# %%
#Import dependencies
import pandas as pd
import numpy as np
import glob
import os

# %% [markdown]
# ### Import & Merge County Data

# %%
#Import multiple CSV files into 1 dataframe
path= os.path.join("Resources", "CountyWeather")
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    #Add a new column that recognizes the name of the CSV file
    df['COUNTY'] = os.path.basename(filename)
    li.append(df)

county_df = pd.concat(li, axis=0, ignore_index=True)
county_df.head()
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031      163.7
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031      163.7
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031      163.7
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031      163.7
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031      163.7
#
#       DATE  AWND AWND_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  \
# 0  2013-01   NaN             NaN   NaN             NaN  45.4              ,U
# 1  2013-02   NaN             NaN   NaN             NaN  48.5              ,U
# 2  2013-03   NaN             NaN   NaN             NaN  58.2              ,U
# 3  2013-04   NaN             NaN   NaN             NaN  63.5              ,U
# 4  2013-05   NaN             NaN   NaN             NaN  67.2              ,U
#
#    TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES        COUNTY
# 0  60.6            ,,,U  30.3            ,,,U  Monterey.csv
# 1  64.7            ,,,U  32.2            ,,,U  Monterey.csv
# 2  75.8            ,,,U  40.6            ,,,U  Monterey.csv
# 3  81.5            ,,,U  45.6            ,,,U  Monterey.csv
# 4  84.9            ,,,U  49.4            ,,,U  Monterey.csv

# %% [markdown]
# ### Review & cleanse data

# %%
#Drop excess columns
county_df = county_df.drop(['ELEVATION','PRCP_ATTRIBUTES','TAVG_ATTRIBUTES','TMAX_ATTRIBUTES',
                            'TMIN_ATTRIBUTES','AWND_ATTRIBUTES'],1)
county_df.tail()
# Out:
#            STATION                     NAME   LATITUDE   LONGITUDE     DATE  \
# 87203  US1CAAL0008  BERKELEY 3.8 ESE, CA US  37.855675 -122.230053  2012-12
# 87204  US1CAAL0008  BERKELEY 3.8 ESE, CA US  37.855675 -122.230053  2013-01
# 87205  US1CAAL0008  BERKELEY 3.8 ESE, CA US  37.855675 -122.230053  2013-02
# 87206  US1CAAL0008  BERKELEY 3.8 ESE, CA US  37.855675 -122.230053  2013-03
# 87207  US1CAAL0008  BERKELEY 3.8 ESE, CA US  37.855675 -122.230053  2013-04
#
#        AWND  PRCP  TAVG  TMAX  TMIN       COUNTY
# 87203   NaN  8.21   NaN   NaN   NaN  Alameda.csv
# 87204   NaN  0.38   NaN   NaN   NaN  Alameda.csv
# 87205   NaN  0.50   NaN   NaN   NaN  Alameda.csv
# 87206   NaN  0.92   NaN   NaN   NaN  Alameda.csv
# 87207   NaN  1.39   NaN   NaN   NaN  Alameda.csv

# %%
#Confirm datatypes for each column
county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87208 entries, 0 to 87207
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    87208 non-null  object
#  1   NAME       87208 non-null  object
#  2   LATITUDE   87208 non-null  float64
#  3   LONGITUDE  87208 non-null  float64
#  4   DATE       87208 non-null  object
#  5   AWND       6962 non-null   float64
#  6   PRCP       65601 non-null  float64
#  7   TAVG       47611 non-null  float64
#  8   TMAX       48173 non-null  float64
#  9   TMIN       48058 non-null  float64
#  10  COUNTY     87208 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 7.3+ MB

# %%
#Check for null data
county_df.count()
# Out:
# STATION      87208
# NAME         87208
# LATITUDE     87208
# LONGITUDE    87208
# DATE         87208
# AWND          6962
# PRCP         65601
# TAVG         47611
# TMAX         48173
# TMIN         48058
# COUNTY       87208
# dtype: int64

# %%
# Drop the .csv from the County column
county_df['COUNTY'] = county_df['COUNTY'].str.replace(r'\.csv', '')
county_df.head()
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  AWND  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    PRCP  TAVG  TMAX  TMIN    COUNTY
# 0   NaN  45.4  60.6  30.3  Monterey
# 1   NaN  48.5  64.7  32.2  Monterey
# 2   NaN  58.2  75.8  40.6  Monterey
# 3   NaN  63.5  81.5  45.6  Monterey
# 4   NaN  67.2  84.9  49.4  Monterey

# %%
# Collapse SD1 & SD2, LA1 & LA2
county_df['COUNTY'] = county_df['COUNTY'].str.replace(r'(_).*', '')
county_df.head()

# dataframe.column.str.replace("(::).*","")
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  AWND  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    PRCP  TAVG  TMAX  TMIN    COUNTY
# 0   NaN  45.4  60.6  30.3  Monterey
# 1   NaN  48.5  64.7  32.2  Monterey
# 2   NaN  58.2  75.8  40.6  Monterey
# 3   NaN  63.5  81.5  45.6  Monterey
# 4   NaN  67.2  84.9  49.4  Monterey

# %% [markdown]
# ### Drop unneeded data
# AWND, TAVG & TMIN

# %%
#Drop columns
county_df = county_df.drop(['AWND','TAVG','TMIN',],1)
# county_df.tail()
county_df.count()
# Out:
# STATION      87208
# NAME         87208
# LATITUDE     87208
# LONGITUDE    87208
# DATE         87208
# PRCP         65601
# TMAX         48173
# COUNTY       87208
# dtype: int64

# %% [markdown]
# ## Calculate missing data & replace NaNs

# %% [markdown]
# ### Calculate TMAX median

# %%
#Group the DF by County & Date, then calculate 
MED = county_df.groupby(['COUNTY','DATE'])[['TMAX']].apply(np.nanmedian)
MED.name = 'MEDIAN_TMAX'
county_df = county_df.join(MED, on=['COUNTY','DATE'])
county_df.head()
# Out:
# /Users/kaitlin/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  PRCP  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    TMAX    COUNTY  MEDIAN_TMAX
# 0  60.6  Monterey        60.75
# 1  64.7  Monterey        62.05
# 2  75.8  Monterey        67.60
# 3  81.5  Monterey        69.35
# 4  84.9  Monterey        73.70

# %%
#Determine if any NaNs in MEDIAN_TMAX
county_df.isna().sum()
# Out:
# STATION            0
# NAME               0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# PRCP           21607
# TMAX           39035
# COUNTY             0
# MEDIAN_TMAX      248
# dtype: int64

# %%
#Drop the NaNs in MEDIAN_TMAX
county_df = county_df[county_df['MEDIAN_TMAX'].notna()]
county_df.isna().sum()
# Out:
# STATION            0
# NAME               0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# PRCP           21604
# TMAX           38787
# COUNTY             0
# MEDIAN_TMAX        0
# dtype: int64

# %% [markdown]
# ### Calculate TMAX maximum

# %%
#Group the DF by County & Date, then calculate 
MAX = county_df.groupby(['COUNTY','DATE'])[['TMAX']].apply(np.nanmax)
MAX.name = 'MAXIM_TMAX'
county_df = county_df.join(MAX, on=['COUNTY','DATE'])
county_df.head()
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  PRCP  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    TMAX    COUNTY  MEDIAN_TMAX  MAXIM_TMAX
# 0  60.6  Monterey        60.75        64.2
# 1  64.7  Monterey        62.05        65.8
# 2  75.8  Monterey        67.60        75.8
# 3  81.5  Monterey        69.35        81.5
# 4  84.9  Monterey        73.70        84.9

# %%
#Determine if any NaNs in MAXIM_TMAX
county_df.isna().sum()
# Out:
# STATION            0
# NAME               0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# PRCP           21604
# TMAX           38787
# COUNTY             0
# MEDIAN_TMAX        0
# MAXIM_TMAX         0
# dtype: int64

# %% [markdown]
# ### Calculate PRCP mean

# %%
#Group the DF by County & Date, then calculate 
MEAN = county_df.groupby(['COUNTY','DATE'])[['PRCP']].apply(np.nanmean)
MEAN.name = 'MEAN_PRCP'
county_df = county_df.join(MEAN, on=['COUNTY','DATE'])
county_df.head()
# Out:
# /Users/kaitlin/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py:965: RuntimeWarning: Mean of empty slice
#   return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  PRCP  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    TMAX    COUNTY  MEDIAN_TMAX  MAXIM_TMAX  MEAN_PRCP
# 0  60.6  Monterey        60.75        64.2   1.181500
# 1  64.7  Monterey        62.05        65.8   0.660526
# 2  75.8  Monterey        67.60        75.8   0.725000
# 3  81.5  Monterey        69.35        81.5   0.407778
# 4  84.9  Monterey        73.70        84.9   0.030588

# %%
#Determine if any NaNs in MEAN_PRCP
county_df.isna().sum()
# Out:
# STATION            0
# NAME               0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# PRCP           21604
# TMAX           38787
# COUNTY             0
# MEDIAN_TMAX        0
# MAXIM_TMAX         0
# MEAN_PRCP         26
# dtype: int64

# %%
#Drop the NaNs in MEAN_PRCP
county_df = county_df[county_df['MEAN_PRCP'].notna()]
county_df.isna().sum()
# Out:
# STATION            0
# NAME               0
# LATITUDE           0
# LONGITUDE          0
# DATE               0
# PRCP           21578
# TMAX           38787
# COUNTY             0
# MEDIAN_TMAX        0
# MAXIM_TMAX         0
# MEAN_PRCP          0
# dtype: int64

# %%
county_df.count()
# Out:
# STATION        86934
# NAME           86934
# LATITUDE       86934
# LONGITUDE      86934
# DATE           86934
# PRCP           65356
# TMAX           48147
# COUNTY         86934
# MEDIAN_TMAX    86934
# MAXIM_TMAX     86934
# MEAN_PRCP      86934
# dtype: int64

# %% [markdown]
# ### Calculate monthly precipitation

# %%
#Group the DF by County & Date, then calculate 
SUM = county_df.groupby(['COUNTY','DATE'])[['PRCP']].apply(np.nansum)
SUM.name = 'SUM_PRCP'
county_df = county_df.join(SUM, on=['COUNTY','DATE'])
county_df.head()
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE     DATE  PRCP  \
# 0  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-01   NaN
# 1  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-02   NaN
# 2  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-03   NaN
# 3  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-04   NaN
# 4  USR0000CBDY  BRADLEY CALIFORNIA, CA US   35.8644  -120.8031  2013-05   NaN
#
#    TMAX    COUNTY  MEDIAN_TMAX  MAXIM_TMAX  MEAN_PRCP  SUM_PRCP
# 0  60.6  Monterey        60.75        64.2   1.181500     23.63
# 1  64.7  Monterey        62.05        65.8   0.660526     12.55
# 2  75.8  Monterey        67.60        75.8   0.725000     13.05
# 3  81.5  Monterey        69.35        81.5   0.407778      7.34
# 4  84.9  Monterey        73.70        84.9   0.030588      0.52

# %%
#Check data for one month to check the columns created properly
county_df[county_df["DATE"]=='2013-01']
# Out:
#            STATION                                  NAME   LATITUDE  \
# 0      USR0000CBDY             BRADLEY CALIFORNIA, CA US  35.864400
# 84     US1CAMT0023                BIG SUR 9.5 NNW, CA US  36.398021
# 144    US1CAMT0022  CARMEL VALLEY VILLAGE 5.4 WNW, CA US  36.521800
# 162    USC00044555                      KING CITY, CA US  36.206900
# 246    US1CAMT0021                 MARINA 0.8 SSE, CA US  36.673173
# ...            ...                                   ...        ...
# 86844  USR0000COKS       OAKLAND SOUTH CALIFORNIA, CA US  37.786100
# 86940  USR0000CCLV      CALAVERAS ROAD CALIFORNIA, CA US  37.553100
# 87035  USC00046144                         NEWARK, CA US  37.514700
# 87131  US1CAAL0007                FREMONT 2.6 ESE, CA US  37.515049
# 87204  US1CAAL0008               BERKELEY 3.8 ESE, CA US  37.855675
#
#         LONGITUDE     DATE  PRCP  TMAX    COUNTY  MEDIAN_TMAX  MAXIM_TMAX  \
# 0     -120.803100  2013-01   NaN  60.6  Monterey        60.75        64.2
# 84    -121.868511  2013-01  2.92   NaN  Monterey        60.75        64.2
# 144   -121.810000  2013-01  1.77   NaN  Monterey        60.75        64.2
# 162   -121.137700  2013-01  0.71  63.1  Monterey        60.75        64.2
# 246   -121.784101  2013-01  0.69   NaN  Monterey        60.75        64.2
# ...           ...      ...   ...   ...       ...          ...         ...
# 86844 -122.144700  2013-01   NaN  54.0   Alameda        56.00        60.5
# 86940 -121.843900  2013-01   NaN  52.0   Alameda        56.00        60.5
# 87035 -122.032500  2013-01  0.27  56.3   Alameda        56.00        60.5
# 87131 -121.952305  2013-01  0.43   NaN   Alameda        56.00        60.5
# 87204 -122.230053  2013-01  0.38   NaN   Alameda        56.00        60.5
#
#        MEAN_PRCP  SUM_PRCP
# 0       1.181500     23.63
# 84      1.181500     23.63
# 144     1.181500     23.63
# 162     1.181500     23.63
# 246     1.181500     23.63
# ...          ...       ...
# 86844   0.555625      8.89
# 86940   0.555625      8.89
# 87035   0.555625      8.89
# 87131   0.555625      8.89
# 87204   0.555625      8.89
#
# [942 rows x 12 columns]

# %% [markdown]
# ### Export CSV

# %%
county_df.to_csv("Resources/county_clean.csv")

# %% [markdown]
# ### Merge & Export CSV

# %%
wildfire_df = pd.read_csv("Resources/wildfire_clean.csv")
wildfire_df.head()
# Out:
#    Unnamed: 0  AcresBurned  ArchiveYear     Counties CountyIds  CrewsInvolved  \
# 0           0     257314.0         2013     Tuolumne        55            NaN
# 1           1      30274.0         2013  Los Angeles        19            NaN
# 2           2      27531.0         2013    Riverside        33            NaN
# 3           3      27440.0         2013       Placer        31            NaN
# 4           4      24251.0         2013      Ventura        56           47.0
#
#    Fatalities   Latitude   Longitude             Name  PersonnelInvolved  \
# 0         NaN  37.857000 -120.086000         Rim Fire                NaN
# 1         NaN  34.585595 -118.423176  Powerhouse Fire                NaN
# 2         NaN  33.709500 -116.728850    Mountain Fire                NaN
# 3         NaN  39.120000 -120.650000    American Fire                NaN
# 4         NaN   0.000000    0.000000     Springs Fire             2167.0
#
#                      Started  StructuresDamaged  StructuresDestroyed  \
# 0  2013-08-17 15:25:00+00:00                NaN                  NaN
# 1  2013-05-30 15:28:00+00:00                NaN                  NaN
# 2  2013-07-15 13:43:00+00:00                NaN                  NaN
# 3  2013-08-10 16:30:00+00:00                NaN                  NaN
# 4  2013-05-02 07:01:00+00:00                6.0                 10.0
#
#                                UniqueId  Year  Month Year-Month
# 0  5fb18d4d-213f-4d83-a179-daaf11939e78  2013      8    2013-08
# 1  bf37805e-1cc2-4208-9972-753e47874c87  2013      5    2013-05
# 2  a3149fec-4d48-427c-8b2c-59e8b79d59db  2013      7    2013-07
# 3  8213f5c7-34fa-403b-a4bc-da2ace6e6625  2013      8    2013-08
# 4  46731fb8-3350-4920-bdf7-910ac0eb715c  2013      5    2013-05

# %%
#Join wildfire & county data on COUNTY NAME & DATE
# merged_df = left_df.merge(right_df, how='inner', left_on=["A", "B"], right_on=["A2","B2"])

wildfire_county_df = wildfire_df.merge(county_df, left_on=['Counties','Year-Month'], right_on=['COUNTY', 'DATE'])
wildfire_county_df.head()
# Out:
#    Unnamed: 0  AcresBurned  ArchiveYear   Counties CountyIds  CrewsInvolved  \
# 0           0     257314.0         2013   Tuolumne        55            NaN
# 1          26       1070.0         2013   Tuolumne        55            NaN
# 2           2      27531.0         2013  Riverside        33            NaN
# 3           2      27531.0         2013  Riverside        33            NaN
# 4           2      27531.0         2013  Riverside        33            NaN
#
#    Fatalities  Latitude  Longitude           Name  ...  LATITUDE LONGITUDE  \
# 0         NaN  37.85700 -120.08600       Rim Fire  ...   37.8769 -119.3436
# 1         NaN  38.25108 -120.02778     Power Fire  ...   37.8769 -119.3436
# 2         NaN  33.70950 -116.72885  Mountain Fire  ...   33.9511 -117.3880
# 3         NaN  33.70950 -116.72885  Mountain Fire  ...   34.0178 -116.1878
# 4         NaN  33.70950 -116.72885  Mountain Fire  ...   34.0608 -114.7322
#
#       DATE  PRCP   TMAX     COUNTY  MEDIAN_TMAX MAXIM_TMAX MEAN_PRCP SUM_PRCP
# 0  2013-08  0.59   68.3   Tuolumne         68.3       68.3  0.590000     0.59
# 1  2013-08  0.59   68.3   Tuolumne         68.3       68.3  0.590000     0.59
# 2  2013-07  0.20   92.6  Riverside         96.6      107.6  0.217778     5.88
# 3  2013-07   NaN   92.1  Riverside         96.6      107.6  0.217778     5.88
# 4  2013-07   NaN  107.1  Riverside         96.6      107.6  0.217778     5.88
#
# [5 rows x 30 columns]

# %%
#Count records
wildfire_county_df.count()
# Out:
# Unnamed: 0             21790
# AcresBurned            21790
# ArchiveYear            21790
# Counties               21790
# CountyIds              21790
# CrewsInvolved           2247
# Fatalities               179
# Latitude               21790
# Longitude              21790
# Name                   21790
# PersonnelInvolved       2671
# Started                21790
# StructuresDamaged        814
# StructuresDestroyed     1955
# UniqueId               21790
# Year                   21790
# Month                  21790
# Year-Month             21790
# STATION                21790
# NAME                   21790
# LATITUDE               21790
# LONGITUDE              21790
# DATE                   21790
# PRCP                   15393
# TMAX                   12675
# COUNTY                 21790
# MEDIAN_TMAX            21790
# MAXIM_TMAX             21790
# MEAN_PRCP              21790
# SUM_PRCP               21790
# dtype: int64

# %%
#Count NaNs
wildfire_county_df.isna().sum()
# Out:
# Unnamed: 0                 0
# AcresBurned                0
# ArchiveYear                0
# Counties                   0
# CountyIds                  0
# CrewsInvolved          19543
# Fatalities             21611
# Latitude                   0
# Longitude                  0
# Name                       0
# PersonnelInvolved      19119
# Started                    0
# StructuresDamaged      20976
# StructuresDestroyed    19835
# UniqueId                   0
# Year                       0
# Month                      0
# Year-Month                 0
# STATION                    0
# NAME                       0
# LATITUDE                   0
# LONGITUDE                  0
# DATE                       0
# PRCP                    6397
# TMAX                    9115
# COUNTY                     0
# MEDIAN_TMAX                0
# MAXIM_TMAX                 0
# MEAN_PRCP                  0
# SUM_PRCP                   0
# dtype: int64

# %%
wildfire_county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21790 entries, 0 to 21789
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           21790 non-null  int64
#  1   AcresBurned          21790 non-null  float64
#  2   ArchiveYear          21790 non-null  int64
#  3   Counties             21790 non-null  object
#  4   CountyIds            21790 non-null  object
#  5   CrewsInvolved        2247 non-null   float64
#  6   Fatalities           179 non-null    float64
#  7   Latitude             21790 non-null  float64
#  8   Longitude            21790 non-null  float64
#  9   Name                 21790 non-null  object
#  10  PersonnelInvolved    2671 non-null   float64
#  11  Started              21790 non-null  object
#  12  StructuresDamaged    814 non-null    float64
#  13  StructuresDestroyed  1955 non-null   float64
#  14  UniqueId             21790 non-null  object
#  15  Year                 21790 non-null  int64
#  16  Month                21790 non-null  int64
#  17  Year-Month           21790 non-null  object
#  18  STATION              21790 non-null  object
#  19  NAME                 21790 non-null  object
#  20  LATITUDE             21790 non-null  float64
#  21  LONGITUDE            21790 non-null  float64
#  22  DATE                 21790 non-null  object
#  23  PRCP                 15393 non-null  float64
#  24  TMAX                 12675 non-null  float64
#  25  COUNTY               21790 non-null  object
#  26  MEDIAN_TMAX          21790 non-null  float64
#  27  MAXIM_TMAX           21790 non-null  float64
#  28  MEAN_PRCP            21790 non-null  float64
#  29  SUM_PRCP             21790 non-null  float64
# dtypes: float64(16), int64(4), object(10)
# memory usage: 5.2+ MB

# %%
#Drop duplicate columns
wildfire_county_df = wildfire_county_df.drop(['Latitude', 'Longitude','Started','COUNTY'],1)

# county_df = county_df.drop(['ELEVATION','PRCP_ATTRIBUTES','TAVG_ATTRIBUTES','TMAX_ATTRIBUTES',
#                             'TMIN_ATTRIBUTES','AWND_ATTRIBUTES'],1)

# %%
wildfire_county_df.to_csv("Resources/wildfire_county_clean.csv")
