# %%
#Import dependencies
import pandas as pd
import numpy as np
import glob
import os

# %% [markdown]
# ### Import & Cleanse Top 20 Data

# %%
#  Import and read the Wildfire CSV.
top20_df = pd.read_csv("Resources/top_20_CA_wildfires.csv")
top20_df
# Out:
#                   fire_name                cause      month  year  \
# 0         Mendocino Complex  Under Investigation       July  2018
# 1                    Thomas           Powerlines   December  2017
# 2                     Cedar        Human Related    October  2003
# 3                      Rush            Lightning     August  2012
# 4                       Rim        Human Related     August  2013
# 5                      Zaca        Human Related       July  2007
# 6                      Carr        Human Related       July  2018
# 7                  Matilija         Undetermined  September  1932
# 8                     Witch           Powerlines    October  2007
# 9   Klamath Theater Complex            Lightning       June  2008
# 10              Marble Cone            Lightning       July  1977
# 11                   Laguna           Powerlines  September  1970
# 12            Basin Complex            Lightning       June  2008
# ...

# %%
#Data is out of date, replace Mendocino Complex "Under Investigation" with latest information "Human Related"
top20_df.at[0, 'cause'] = "Human Related"
top20_df
# Out:
#                   fire_name          cause      month  year  \
# 0         Mendocino Complex  Human Related       July  2018
# 1                    Thomas     Powerlines   December  2017
# 2                     Cedar  Human Related    October  2003
# 3                      Rush      Lightning     August  2012
# 4                       Rim  Human Related     August  2013
# 5                      Zaca  Human Related       July  2007
# 6                      Carr  Human Related       July  2018
# 7                  Matilija   Undetermined  September  1932
# 8                     Witch     Powerlines    October  2007
# 9   Klamath Theater Complex      Lightning       June  2008
# 10              Marble Cone      Lightning       July  1977
# 11                   Laguna     Powerlines  September  1970
# 12            Basin Complex      Lightning       June  2008
# 13                 Day Fire  Human Related  September  2006
# 14                  Station  Human Related     August  2009
# ...

# %%
cause = top20_df.groupby('cause')['acres'].sum()
cause
# Out:
# cause
# Human Related    1933496
# Lightning        1243184
# Powerlines        808644
# Undetermined      220000
# Name: acres, dtype: int64

# %%
year = top20_df[top20_df.year > 2012]
year
# Out:
#             fire_name          cause     month  year  \
# 0   Mendocino Complex  Human Related      July  2018
# 1              Thomas     Powerlines  December  2017
# 4                 Rim  Human Related    August  2013
# 6                Carr  Human Related      July  2018
# 15          Camp Fire     Powerlines  November  2018
# 16              Rough      Lightning      July  2015
#
#                                                county   acres  structures  \
# 0   Colusa County, Lake County, Mendocino County &...  459123         280
# 1                             Ventura & Santa Barbara  281893        1063
# 4                                            Tuolumne  257314         112
# 6                        Shasta County,Trinity County  229651        1614
# 15                                              Butte  153336       18804
# 16                                             Fresno  151623           4
#
#     deaths
# 0        1
# 1        2
# 4        0
# 6        8
# ...

# %% [markdown]
# ### Export CSV

# %%
year.to_csv("Resources/top_fire_clean.csv")
